# %% [markdown]
# # MUHAMMAD SAAD ALI

# %% [markdown]
# ### DATA SCIENCE AND BUSINESS ANALYTICS

# %% [markdown]
# ### TASK NO:3 - EXPLORATORY DATA ANALYSIS - RETAIL

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('SampleSuperstore.csv')

# %%
storestyle = df.head(20)

# %%
storestyle.style.background_gradient(cmap = 'PuBu')
# Out:
# <style type="text/css">
# #T_94e6d_row0_col5, #T_94e6d_row1_col5 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_94e6d_row0_col9 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_94e6d_row0_col10, #T_94e6d_row0_col11, #T_94e6d_row1_col11, #T_94e6d_row2_col10, #T_94e6d_row2_col11, #T_94e6d_row3_col12, #T_94e6d_row4_col10, #T_94e6d_row5_col11, #T_94e6d_row6_col9, #T_94e6d_row6_col11, #T_94e6d_row9_col11, #T_94e6d_row12_col5, #T_94e6d_row15_col9, #T_94e6d_row16_col11, #T_94e6d_row17_col10, #T_94e6d_row17_col11, #T_94e6d_row18_col9, #T_94e6d_row18_col10, #T_94e6d_row18_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_94e6d_row0_col12 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_94e6d_row1_col9, #T_94e6d_row3_col10, #T_94e6d_row9_col10, #T_94e6d_row14_col10 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_94e6d_row1_col10, #T_94e6d_row8_col10, #T_94e6d_row12_col10, #T_94e6d_row13_col10, #T_94e6d_row15_col10, #T_94e6d_row19_col10 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_94e6d_row1_col12, #T_94e6d_row10_col9, #T_94e6d_row10_col10, #T_94e6d_row13_col5, #T_94e6d_row14_col11, #T_94e6d_row15_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_94e6d_row2_col5, #T_94e6d_row5_col5, #T_94e6d_row6_col5, #T_94e6d_row7_col5, #T_94e6d_row8_col5, #T_94e6d_row9_col5, #T_94e6d_row10_col5, #T_94e6d_row11_col5 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_94e6d_row2_col9, #T_94e6d_row12_col9 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_94e6d_row2_col12, #T_94e6d_row8_col12, #T_94e6d_row12_col12 {
#   background-color: #2d8abd;
#   color: #f1f1f1;
# }
# #T_94e6d_row3_col5, #T_94e6d_row4_col5 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_94e6d_row3_col9 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_94e6d_row3_col11 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_94e6d_row4_col9, #T_94e6d_row8_col9 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_94e6d_row4_col11, #T_94e6d_row7_col11, #T_94e6d_row8_col11, #T_94e6d_row10_col11, #T_94e6d_row11_col11, #T_94e6d_row12_col11, #T_94e6d_row13_col11, #T_94e6d_row19_col11 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_94e6d_row4_col12, #T_94e6d_row6_col12, #T_94e6d_row18_col12 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_94e6d_row5_col9 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_94e6d_row5_col10 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_94e6d_row5_col12, #T_94e6d_row16_col12 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_94e6d_row6_col10, #T_94e6d_row11_col10 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_94e6d_row7_col9 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_94e6d_row7_col10, #T_94e6d_row16_col10 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_94e6d_row7_col12 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_94e6d_row9_col9 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_94e6d_row9_col12 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_94e6d_row10_col12 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_94e6d_row11_col9 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_94e6d_row11_col12 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_94e6d_row13_col9 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_94e6d_row13_col12 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_94e6d_row14_col5, #T_94e6d_row15_col5 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_94e6d_row14_col9 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_94e6d_row14_col12 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_94e6d_row15_col12 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_94e6d_row16_col5 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_94e6d_row16_col9 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_94e6d_row17_col5 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_94e6d_row17_col9 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_94e6d_row17_col12 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_94e6d_row18_col5, #T_94e6d_row19_col5 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_94e6d_row19_col9 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_94e6d_row19_col12 {
#   background-color: #2786bb;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_94e6d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94e6d_level0_col0" class="col_heading level0 col0" >Ship Mode</th>
#       <th id="T_94e6d_level0_col1" class="col_heading level0 col1" >Segment</th>
#       <th id="T_94e6d_level0_col2" class="col_heading level0 col2" >Country</th>
#       <th id="T_94e6d_level0_col3" class="col_heading level0 col3" >City</th>
#       <th id="T_94e6d_level0_col4" class="col_heading level0 col4" >State</th>
#       <th id="T_94e6d_level0_col5" class="col_heading level0 col5" >Postal Code</th>
#       <th id="T_94e6d_level0_col6" class="col_heading level0 col6" >Region</th>
#       <th id="T_94e6d_level0_col7" class="col_heading level0 col7" >Category</th>
#       <th id="T_94e6d_level0_col8" class="col_heading level0 col8" >Sub-Category</th>
#       <th id="T_94e6d_level0_col9" class="col_heading level0 col9" >Sales</th>
#       <th id="T_94e6d_level0_col10" class="col_heading level0 col10" >Quantity</th>
#       <th id="T_94e6d_level0_col11" class="col_heading level0 col11" >Discount</th>
#       <th id="T_94e6d_level0_col12" class="col_heading level0 col12" >Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94e6d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94e6d_row0_col0" class="data row0 col0" >Second Class</td>
#       <td id="T_94e6d_row0_col1" class="data row0 col1" >Consumer</td>
#       <td id="T_94e6d_row0_col2" class="data row0 col2" >United States</td>
#       <td id="T_94e6d_row0_col3" class="data row0 col3" >Henderson</td>
#       <td id="T_94e6d_row0_col4" class="data row0 col4" >Kentucky</td>
#       <td id="T_94e6d_row0_col5" class="data row0 col5" >42420</td>
#       <td id="T_94e6d_row0_col6" class="data row0 col6" >South</td>
#       <td id="T_94e6d_row0_col7" class="data row0 col7" >Furniture</td>
#       <td id="T_94e6d_row0_col8" class="data row0 col8" >Bookcases</td>
#       <td id="T_94e6d_row0_col9" class="data row0 col9" >261.960000</td>
#       <td id="T_94e6d_row0_col10" class="data row0 col10" >2</td>
#       <td id="T_94e6d_row0_col11" class="data row0 col11" >0.000000</td>
#       <td id="T_94e6d_row0_col12" class="data row0 col12" >41.913600</td>
#     </tr>
#     <tr>
#       <th id="T_94e6d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94e6d_row1_col0" class="data row1 col0" >Second Class</td>
#       <td id="T_94e6d_row1_col1" class="data row1 col1" >Consumer</td>
#       <td id="T_94e6d_row1_col2" class="data row1 col2" >United States</td>
#       <td id="T_94e6d_row1_col3" class="data row1 col3" >Henderson</td>
#       <td id="T_94e6d_row1_col4" class="data row1 col4" >Kentucky</td>
#       <td id="T_94e6d_row1_col5" class="data row1 col5" >42420</td>
#       <td id="T_94e6d_row1_col6" class="data row1 col6" >South</td>
#       <td id="T_94e6d_row1_col7" class="data row1 col7" >Furniture</td>
#       <td id="T_94e6d_row1_col8" class="data row1 col8" >Chairs</td>
#       <td id="T_94e6d_row1_col9" class="data row1 col9" >731.940000</td>
#       <td id="T_94e6d_row1_col10" class="data row1 col10" >3</td>
#       <td id="T_94e6d_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_94e6d_row1_col12" class="data row1 col12" >219.582000</td>
#     </tr>
#     <tr>
#       <th id="T_94e6d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94e6d_row2_col0" class="data row2 col0" >Second Class</td>
#       <td id="T_94e6d_row2_col1" class="data row2 col1" >Corporate</td>
#       <td id="T_94e6d_row2_col2" class="data row2 col2" >United States</td>
#       <td id="T_94e6d_row2_col3" class="data row2 col3" >Los Angeles</td>
#       <td id="T_94e6d_row2_col4" class="data row2 col4" >California</td>
#       <td id="T_94e6d_row2_col5" class="data row2 col5" >90036</td>
#       <t

# %%
storestyle = df.tail(20)

# %%
storestyle.style.background_gradient(cmap = 'PuBu')
# Out:
# <style type="text/css">
# #T_9220e_row0_col5, #T_9220e_row1_col5, #T_9220e_row2_col5, #T_9220e_row3_col5, #T_9220e_row4_col5, #T_9220e_row5_col5, #T_9220e_row6_col5, #T_9220e_row13_col5 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_9220e_row0_col9 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_9220e_row0_col10, #T_9220e_row8_col10, #T_9220e_row15_col10 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_9220e_row0_col11, #T_9220e_row3_col11, #T_9220e_row5_col11, #T_9220e_row6_col9, #T_9220e_row6_col10, #T_9220e_row6_col11, #T_9220e_row6_col12, #T_9220e_row8_col11, #T_9220e_row16_col11, #T_9220e_row17_col5, #T_9220e_row18_col5, #T_9220e_row18_col11, #T_9220e_row19_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_9220e_row0_col12, #T_9220e_row10_col12 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_9220e_row1_col9 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_9220e_row1_col10, #T_9220e_row4_col10, #T_9220e_row9_col10 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_9220e_row1_col11, #T_9220e_row2_col9, #T_9220e_row2_col11, #T_9220e_row4_col9, #T_9220e_row4_col11, #T_9220e_row4_col12, #T_9220e_row5_col9, #T_9220e_row7_col10, #T_9220e_row7_col11, #T_9220e_row9_col11, #T_9220e_row10_col11, #T_9220e_row11_col5, #T_9220e_row11_col11, #T_9220e_row12_col5, #T_9220e_row12_col11, #T_9220e_row13_col10, #T_9220e_row13_col11, #T_9220e_row14_col10, #T_9220e_row14_col11, #T_9220e_row15_col11, #T_9220e_row17_col11, #T_9220e_row19_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_9220e_row1_col12, #T_9220e_row8_col12 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_9220e_row2_col10, #T_9220e_row3_col10, #T_9220e_row10_col10, #T_9220e_row17_col10, #T_9220e_row18_col10 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_9220e_row2_col12, #T_9220e_row11_col9 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_9220e_row3_col9 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_9220e_row3_col12 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_9220e_row5_col10, #T_9220e_row12_col10, #T_9220e_row19_col10 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_9220e_row5_col12, #T_9220e_row16_col9 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_9220e_row7_col5 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_9220e_row7_col9 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_9220e_row7_col12 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_9220e_row8_col5 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_9220e_row8_col9 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_9220e_row9_col5, #T_9220e_row10_col5 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_9220e_row9_col9, #T_9220e_row13_col9 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_9220e_row9_col12 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_9220e_row10_col9 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_9220e_row11_col10 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_9220e_row11_col12, #T_9220e_row12_col9, #T_9220e_row12_col12, #T_9220e_row13_col12, #T_9220e_row17_col12 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_9220e_row14_col5, #T_9220e_row15_col5 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_9220e_row14_col9 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_9220e_row14_col12 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_9220e_row15_col9 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_9220e_row15_col12 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_9220e_row16_col5 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_9220e_row16_col10 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_9220e_row16_col12 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_9220e_row17_col9 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_9220e_row18_col9 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_9220e_row18_col12 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_9220e_row19_col9 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_9220e_row19_col12 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_9220e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9220e_level0_col0" class="col_heading level0 col0" >Ship Mode</th>
#       <th id="T_9220e_level0_col1" class="col_heading level0 col1" >Segment</th>
#       <th id="T_9220e_level0_col2" class="col_heading level0 col2" >Country</th>
#       <th id="T_9220e_level0_col3" class="col_heading level0 col3" >City</th>
#       <th id="T_9220e_level0_col4" class="col_heading level0 col4" >State</th>
#       <th id="T_9220e_level0_col5" class="col_heading level0 col5" >Postal Code</th>
#       <th id="T_9220e_level0_col6" class="col_heading level0 col6" >Region</th>
#       <th id="T_9220e_level0_col7" class="col_heading level0 col7" >Category</th>
#       <th id="T_9220e_level0_col8" class="col_heading level0 col8" >Sub-Category</th>
#       <th id="T_9220e_level0_col9" class="col_heading level0 col9" >Sales</th>
#       <th id="T_9220e_level0_col10" class="col_heading level0 col10" >Quantity</th>
#       <th id="T_9220e_level0_col11" class="col_heading level0 col11" >Discount</th>
#       <th id="T_9220e_level0_col12" class="col_heading level0 col12" >Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9220e_level0_row0" class="row_heading level0 row0" >9973</th>
#       <td id="T_9220e_row0_col0" class="data row0 col0" >Standard Class</td>
#       <td id="T_9220e_row0_col1" class="data row0 col1" >Home Office</td>
#       <td id="T_9220e_row0_col2" class="data row0 col2" >United States</td>
#       <td id="T_9220e_row0_col3" class="data row0 col3" >Los Angeles</td>
#       <td id="T_9220e_row0_col4" class="data row0 col4" >California</td>
#       <td id="T_9220e_row0_col5" class="data row0 col5" >90032</td>
#       <td id="T_9220e_row0_col6" class="data row0 col6" >West</td>
#       <td id="T_9220e_row0_col7" class="data row0 col7" >Technology</td>
#       <td id="T_9220e_row0_col8" class="data row0 col8" >Phones</td>
#       <td id="T_9220e_row0_col9" class="data row0 col9" >271.960000</td>
#       <td id="T_9220e_row0_col10" class="data row0 col10" >5</td>
#       <td id="T_9220e_row0_col11" class="data row0 col11" >0.200000</td>
#       <td id="T_9220e_row0_col12" class="data row0 col12" >27.196000</td>
#     </tr>
#     <tr>
#       <th id="T_9220e_level0_row1" class="row_heading level0 row1" >9974</th>
#       <td id="T_9220e_row1_col0" class="data row1 col0" >Standard Class</td>
#       <td id="T_9220e_row1_col1" class="data row1 col1" >Home Office</td>
#       <td id="T_9220e_row1_col2" class="data row1 col2" >United States</td>
#       <td id="T_9220e_row1_col3" class="data row1 col3" >Los Angeles</td>
#       <td id="T_9220e_row1_col4" class="data row1 col4" >California</td>
#       <td id="T_9220e_row1_col5" class="data row1 col5" >90032</td>
#       <td id="T_9220e_row1_col6" class="data row1 col6" >West</td>
#       <td id="T_9220e_row1_col7" class="data row1 col7" >Office Supplies</td>
#       <td id="T_9220e_row1_col8" class="data row1 col8" >Art</td>
#       <td id="T_9220e_row1_col9" class="data row1 col9" >18.690000</td>
#       <td id="T_9220e_row1_col10" class="data row1 col10" >7</td>
#       <td id="T_9220e_row1_col11" class="data row1 col11" >0.000000</td>
#       <td id="T_9220e_row1_col12" class="data row1 col12" >5.233200</td>
#     </tr>
#     <tr>
#       <th id="T_9220e_level0_row2" class="row_heading level0 row2" >9975</th>
#       <td id="T_9220e_row2_col0" class="data row2 col0" >Standard Class</td>
#       <td id="T_9220e_row2_col1" class="data row2 col1" >Home Office</td>
#       <td id="T_9220e_row2_col2" class="data row2 col2" >United States</td>
#       <td id="T_9220e_row2_col3" class="data row2 col3" >Los Angeles</td>
#       <td id="T_9220e_row2_col4" class="data row2 col4" >California</td>
#       <td id="T_9220e_row2_col5" class="data row2 col5" >90032</td>
#       <td id="T_9220e_row2_col6" class="data row2 col6" >West</td>
#       <td id="T_9220e_row2_col7" class="data row2 col7" >Office

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9993, 13)

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5824
# Quantity          14
# Discount          12
# Profit          7286
# dtype: int64

# %%
df.describe().style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_db948_row0_col0 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_db948_row0_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_db948_row0_col2, #T_db948_row0_col3, #T_db948_row0_col4, #T_db948_row7_col0, #T_db948_row7_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_db948_row1_col0 {
#   background-color: #5a9ec9;
#   color: #f1f1f1;
# }
# #T_db948_row1_col1, #T_db948_row6_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_db948_row1_col2, #T_db948_row1_col3, #T_db948_row2_col2, #T_db948_row2_col3, #T_db948_row3_col0, #T_db948_row3_col1, #T_db948_row3_col2, #T_db948_row3_col3, #T_db948_row3_col4, #T_db948_row4_col1, #T_db948_row4_col2, #T_db948_row4_col3, #T_db948_row5_col1, #T_db948_row5_col2, #T_db948_row5_col3, #T_db948_row6_col2, #T_db948_row6_col3, #T_db948_row7_col2, #T_db948_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_db948_row1_col4, #T_db948_row6_col4 {
#   background-color: #9cb9d9;
#   color: #000000;
# }
# #T_db948_row2_col0 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_db948_row2_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_db948_row2_col4 {
#   background-color: #97b7d7;
#   color: #000000;
# }
# #T_db948_row4_col0 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_db948_row4_col4, #T_db948_row5_col4 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_db948_row5_col0 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_db948_row6_col0, #T_db948_row7_col4 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_db948">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db948_level0_col0" class="col_heading level0 col0" >Postal Code</th>
#       <th id="T_db948_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_db948_level0_col2" class="col_heading level0 col2" >Quantity</th>
#       <th id="T_db948_level0_col3" class="col_heading level0 col3" >Discount</th>
#       <th id="T_db948_level0_col4" class="col_heading level0 col4" >Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db948_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_db948_row0_col0" class="data row0 col0" >9993.000000</td>
#       <td id="T_db948_row0_col1" class="data row0 col1" >9993.000000</td>
#       <td id="T_db948_row0_col2" class="data row0 col2" >9993.000000</td>
#       <td id="T_db948_row0_col3" class="data row0 col3" >9993.000000</td>
#       <td id="T_db948_row0_col4" class="data row0 col4" >9993.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db948_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_db948_row1_col0" class="data row1 col0" >55186.627539</td>
#       <td id="T_db948_row1_col1" class="data row1 col1" >229.856670</td>
#       <td id="T_db948_row1_col2" class="data row1 col2" >3.789753</td>
#       <td id="T_db948_row1_col3" class="data row1 col3" >0.156218</td>
#       <td id="T_db948_row1_col4" class="data row1 col4" >28.652464</td>
#     </tr>
#     <tr>
#       <th id="T_db948_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_db948_row2_col0" class="data row2 col0" >32063.103801</td>
#       <td id="T_db948_row2_col1" class="data row2 col1" >623.276273</td>
#       <td id="T_db948_row2_col2" class="data row2 col2" >2.225149</td>
#       <td id="T_db948_row2_col3" class="data row2 col3" >0.206456</td>
#       <td id="T_db948_row2_col4" class="data row2 col4" >234.271411</td>
#     </tr>
#     <tr>
#       <th id="T_db948_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_db948_row3_col0" class="data row3 col0" >1040.000000</td>
#       <td id="T_db948_row3_col1" class="data row3 col1" >0.444000</td>
#       <td id="T_db948_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_db948_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_db948_row3_col4" class="data row3 col4" >-6599.978000</td>
#     </tr>
#     <tr>
#       <th id="T_db948_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_db948_row4_col0" class="data row4 col0" >23223.000000</td>
#       <td id="T_db948_row4_col1" class="data row4 col1" >17.280000</td>
#       <td id="T_db948_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_db948_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_db948_row4_col4" class="data row4 col4" >1.728000</td>
#     </tr>
#     <tr>
#       <th id="T_db948_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_db948_row5_col0" class="data row5 col0" >56301.000000</td>
#       <td id="T_db948_row5_col1" class="data row5 col1" >54.480000</td>
#       <td id="T_db948_row5_col2" class="data row5 col2" >3.000000</td>
#       <td id="T_db948_row5_col3" class="data row5 col3" >0.200000</td>
#       <td id="T_db948_row5_col4" class="data row5 col4" >8.662000</td>
#     </tr>
#     <tr>
#       <th id="T_db948_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_db948_row6_col0" class="data row6 col0" >90008.000000</td>
#       <td id="T_db948_row6_col1" class="data row6 col1" >209.940000</td>
#       <td id="T_db948_row6_col2" class="data row6 col2" >5.000000</td>
#       <td id="T_db948_row6_col3" class="data row6 col3" >0.200000</td>
#       <td id="T_db948_row6_col4" class="data row6 col4" >29.364000</td>
#     </tr>
#     <tr>
#       <th id="T_db948_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_db948_row7_col0" class="data row7 col0" >99301.000000</td>
#       <td id="T_db948_row7_col1" class="data row7 col1" >22638.480000</td>
#       <td id="T_db948_row7_col2" class="data row7 col2" >14.000000</td>
#       <td id="T_db948_row7_col3" class="data row7 col3" >0.800000</td>
#       <td id="T_db948_row7_col4" class="data row7 col4" >8399.976000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9993 non-null   object
#  1   Segment       9993 non-null   object
#  2   Country       9993 non-null   object
#  3   City          9993 non-null   object
#  4   State         9993 non-null   object
#  5   Postal Code   9993 non-null   int64
#  6   Region        9993 non-null   object
#  7   Category      9993 non-null   object
#  8   Sub-Category  9993 non-null   object
#  9   Sales         9993 non-null   float64
#  10  Quantity      9993 non-null   int64
#  11  Discount      9993 non-null   float64
#  12  Profit        9993 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.0+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates(subset=None, keep = 'first', inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Postal Code'] = df['Postal Code'].astype('object')

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Sub-Category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
num_columns = df.select_dtypes(include=[int, float])

# %%
num_columns
# Out:
#          Sales  Quantity  Discount    Profit
# 0     261.9600         2      0.00   41.9136
# 1     731.9400         3      0.00  219.5820
# 2      14.6200         2      0.00    6.8714
# 3     957.5775         5      0.45 -383.0310
# 4      22.3680         2      0.20    2.5164
# ...        ...       ...       ...       ...
# 9988  206.1000         5      0.00   55.6470
# 9989   25.2480         3      0.20    4.1028
# 9990   91.9600         2      0.00   15.6332
# 9991  258.5760         2      0.20   19.3932
# 9992   29.6000         4      0.00   13.3200
#
# [9976 rows x 4 columns]

# %%
cat_columns = df.select_dtypes(include=[object])

# %%
cat_columns
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9988  Standard Class  Corporate  United States           Athens     Georgia
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
#
#      Postal Code Region         Category Sub-Category
# 0          42420  South        Furniture    Bookcases
# 1          42420  South        Furniture       Chairs
# 2          90036   West  Office Supplies       Labels
# 3          33311  South        Furniture       Tables
# 4          33311  South  Office Supplies      Storage
# ...          ...    ...              ...          ...
# 9988       30605  South       Technology       Phones
# 9989       33180  South        Furniture  Furnishings
# 9990       92627   West        Furniture  Furnishings
# 9991       92627   West       Technology       Phones
# 9992       92627   West  Office Supplies        Paper
#
# [9976 rows x 9 columns]

# %%
col = df.columns.to_list()
col
# Out:
# ['Ship Mode',
#  'Segment',
#  'Country',
#  'City',
#  'State',
#  'Postal Code',
#  'Region',
#  'Category',
#  'Sub-Category',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit']

# %%
for i in num_columns:
    sns.distplot(df[i])
    plt.show()

# %%
sns.pairplot(df,hue='Ship Mode',palette='gist_heat')

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df_con = df[df['Segment'] == 'Consumer']
df_corp = df[df['Segment'] == 'Corporate']
df_home = df[df['Segment'] == 'Home Office']

# %%
print(len(df_con))
print(len(df_corp))
print(len(df_home))
# Out:
# 5182
# 3015
# 1779

# %%
df_con.index
# Out:
# Index([   0,    1,    3,    4,    5,    6,    7,    8,    9,   10,
#        ...
#        9981, 9982, 9983, 9984, 9985, 9986, 9989, 9990, 9991, 9992],
#       dtype='int64', length=5182)

# %%
df_con.loc[0]
# Out:
# Ship Mode        Second Class
# Segment              Consumer
# Country         United States
# City                Henderson
# State                Kentucky
# Postal Code             42420
# Region                  South
# Category            Furniture
# Sub-Category        Bookcases
# Sales                  261.96
# Quantity                    2
# Discount                  0.0
# Profit                41.9136
# Name: 0, dtype: object

# %%
x = ['Consumer','Corporate','Head Office']
y = [len(df_con.index), len(df_corp.index), len(df_home.index)]
plt.bar(x,y,color = ['green','yellow','blue'], edgecolor = 'black')
plt.title('Types Of Customer')
plt.xlabel('Customers')
plt.ylabel('Number of Customers')
plt.grid(True)
plt.show()

# %%
state_profit = pd.DataFrame(df.groupby("State")["Profit"].sum())
state_profit.reset_index(inplace = True)
state_profit = state_profit.sort_values(by = "Profit",ascending = False)
state_profit.head(10)
# Out:
#          State      Profit
# 3   California  76257.8411
# 30    New York  74015.4622
# 45  Washington  33368.2375
# 20    Michigan  24428.0903
# 44    Virginia  18597.9504
# 12     Indiana  18382.9363
# 9      Georgia  16250.0433
# 15    Kentucky  11199.6966
# 21   Minnesota  10823.1874
# 6     Delaware   9977.3748

# %%
sub_categories_info = pd.DataFrame(df.groupby("Sub-Category")["Profit"].sum())
sub_categories_info.reset_index(inplace = True)
sub_categories_profit = sub_categories_info.sort_values(by="Profit",ascending = False)
sub_categories_profit.head(10)
# Out:
#    Sub-Category      Profit
# 6       Copiers  55617.8249
# 13       Phones  44515.7306
# 0   Accessories  41936.6357
# 12        Paper  33944.2395
# 3       Binders  30228.0003
# 5        Chairs  26567.1278
# 14      Storage  21278.8264
# 1    Appliances  18065.0574
# 9   Furnishings  13052.7230
# 7     Envelopes   6964.1767

# %%
city_volume = pd.DataFrame(df.groupby('City')['Sales'].sum())
city_volume = city_volume.sort_values(by = "Sales",ascending = False)
city_volume.head()
# Out:
#                     Sales
# City
# New York City  256319.041
# Los Angeles    175831.901
# Seattle        119460.282
# San Francisco  112577.172
# Philadelphia   109061.461

# %%
categories_sales = df.groupby("Category").sum()
categories_sales.reset_index(inplace = True)
categories_sales.head(10)
# Out:
#           Category                                          Ship Mode  \
# 0        Furniture  Second ClassSecond ClassStandard ClassStandard...
# 1  Office Supplies  Second ClassStandard ClassStandard ClassStanda...
# 2       Technology  Standard ClassStandard ClassSecond ClassSecond...
#
#                                              Segment  \
# 0  ConsumerConsumerConsumerConsumerConsumerConsum...
# 1  CorporateConsumerConsumerConsumerConsumerConsu...
# 2  ConsumerConsumerConsumerConsumerCorporateHome ...
#
#                                              Country  \
# 0  United StatesUnited StatesUnited StatesUnited ...
# 1  United StatesUnited StatesUnited StatesUnited ...
# 2  United StatesUnited StatesUnited StatesUnited ...
#
#                                                 City  \
# 0  HendersonHendersonFort LauderdaleLos AngelesLo...
# 1  Los AngelesFort LauderdaleLos AngelesLos Angel...
# 2  Los AngelesLos AngelesSan FranciscoLos Angeles...
#
#                                                State Postal Code  \
# 0  KentuckyKentuckyFloridaCaliforniaCaliforniaPen...   118006465
# 1  CaliforniaFloridaCaliforniaCaliforniaCaliforni...   329578175
# 2  CaliforniaCaliforniaCaliforniaCaliforniaTexasT...   102603754
#
#                                               Region  \
# 0  SouthSouthSouthWestWestEastWestEastEastCentral...
# 1  WestSouthWestWestWestSouthWestCentralCentralCe...
# 2  WestWestWestWestCentralCentralCentralCentralEa...
#
#                                         Sub-Category        Sales  Quantity  \
# 0  BookcasesChairsTablesFurnishingsTablesChairsTa...  741306.3133      8020
# 1  LabelsStorageArtBindersAppliancesPaperBindersA...  718492.0840     22859
# 2  PhonesPhonesPhonesAccessoriesPhonesPhonesPhone...  836154.0330      6939
#
#    Discount       Profit
# 0    368.59   18421.8137
# 1    946.20  122291.7128
# 2    244.40  145454.9481

# %%
plt.bar(categories_sales["Category"], categories_sales['Sales'])
plt.xticks(categories_sales.index)
plt.xlabel("Category")
plt.ylabel("Sales")
plt.show()

# %%
plt.bar(sub_categories_profit["Sub-Category"],sub_categories_profit["Profit"])
plt.xticks(sub_categories_profit['Sub-Category'] , rotation = "vertical")
plt.xlabel("Sub-Categories")
plt.ylabel("Profit")
plt.show()

# %%
popular_sub_category = pd.DataFrame(df.groupby("Sub-Category")["Quantity"].sum())
popular_sub_category.reset_index(inplace = True)
popular_sub_category = popular_sub_category.sort_values(by = "Quantity",ascending=False)

popular_sub_category.head(10)
# Out:
#    Sub-Category  Quantity
# 3       Binders      5971
# 12        Paper      5144
# 9   Furnishings      3560
# 13       Phones      3289
# 14      Storage      3158
# 2           Art      2996
# 0   Accessories      2976
# 5        Chairs      2351
# 1    Appliances      1727
# 10       Labels      1396

# %%
plt.bar(popular_sub_category["Sub-Category"],popular_sub_category["Quantity"],color = "cyan")
plt.xticks(popular_sub_category["Sub-Category"],rotation = "vertical")
plt.title("Sub-Category Vs Quantity")
plt.xlabel("Sub Category")
plt.ylabel("Quantity")
plt.show()

# %%
customer_segment=df.groupby("Segment").sum()
customer_segment.reset_index(inplace=True)

customer_segment.head(10)
# Out:
#        Segment                                          Ship Mode  \
# 0     Consumer  Second ClassSecond ClassStandard ClassStandard...
# 1    Corporate  Second ClassStandard ClassStandard ClassFirst ...
# 2  Home Office  Standard ClassStandard ClassSecond ClassStanda...
#
#                                              Country  \
# 0  United StatesUnited StatesUnited StatesUnited ...
# 1  United StatesUnited StatesUnited StatesUnited ...
# 2  United StatesUnited StatesUnited StatesUnited ...
#
#                                                 City  \
# 0  HendersonHendersonFort LauderdaleFort Lauderda...
# 1  Los AngelesFremontFremontRichardsonRichardsonN...
# 2  Fort WorthFort WorthHoustonHoustonHoustonHoust...
#
#                                                State Postal Code  \
# 0  KentuckyKentuckyFloridaFloridaCaliforniaCalifo...   288176951
# 1  CaliforniaNebraskaNebraskaTexasTexasIllinoisCa...   164108306
# 2  TexasTexasTexasTexasTexasTexasTexasIllinoisIll...    97903137
#
#                                               Region  \
# 0  SouthSouthSouthSouthWestWestWestWestWestWestWe...
# 1  WestCentralCentralCentralCentralCentralWestSou...
# 2  CentralCentralCentralCentralCentralCentralCent...
#
#                                             Category  \
# 0  FurnitureFurnitureFurnitureOffice SuppliesFurn...
# 1  Office SuppliesOffice SuppliesOffice SuppliesT...
# 2  Office SuppliesOffice SuppliesOffice SuppliesO...
#
#                                         Sub-Category         Sales  Quantity  \
# 0  BookcasesChairsTablesStorageFurnishingsArtPhon...  1.160590e+06     19495
# 1  LabelsArtAppliancesPhonesFurnishingsPhonesStor...  7.060701e+05     11591
# 2  AppliancesBindersPaperEnvelopesBookcasesChairs...  4.292927e+05      6732
#
#    Discount       Profit
# 0    820.51  133934.4933
# 1    476.85   91954.9798
# 2    261.83   60279.0015

# %%
plt.bar(customer_segment["Segment"],customer_segment["Profit"],color = "teal")
plt.xticks(customer_segment["Segment"],rotation = "vertical")
plt.title("Segment Vs Profit")
plt.xlabel("Segment")
plt.ylabel("Profit")
plt.show()

# %%
profitable_region=pd.DataFrame(df.groupby("Region")["Profit"].sum())
profitable_region.reset_index(inplace=True)
profitable_region = profitable_region.sort_values(by = "Profit",ascending=False)
profitable_region
# Out:
#     Region       Profit
# 3     West  108256.8599
# 1     East   91506.3092
# 2    South   46749.4303
# 0  Central   39655.8752

# %%
plt.bar(profitable_region["Region"],profitable_region["Profit"],color = "teal")
plt.xticks(profitable_region["Region"],rotation = "vertical")
plt.title("Region Vs Profit")
plt.xlabel("Region")
plt.ylabel("Profit")
plt.show()

# %%
city_volume = pd.DataFrame(df.groupby('City')['Sales'].sum())
city_volume =city_volume.sort_values(by="Sales",ascending=False)
city_volume.head()
# Out:
#                     Sales
# City
# New York City  256319.041
# Los Angeles    175831.901
# Seattle        119460.282
# San Francisco  112577.172
# Philadelphia   109061.461

# %%
plt.bar(city_volume.index[0:20], city_volume['Sales'][0:20],color="teal")
plt.xticks(city_volume.index[0:20],rotation = 'vertical')
plt.xlabel("City" )
plt.ylabel("Sales")
plt.show()
